# %% [markdown]
# ### **1. In the below elements which of them are values or an expression? Example: values can be integer or string and expressions will be mathematical operators.**
#
#
# ```python
# *
# 'hello'
# -87.8
# -
# /
# +
# 6
# ```

# %% [markdown]
# **Answer:**
#
#
# ``` python
# *             # This is expression
# 'hello'       # This is value
# -87.8         # This is value
# -             # This is expression
# /             # This is expression
# +             # This is expression
# 6             # This is values
# ```

# %% [markdown]
# ### **2. What is the difference between string and variable?**

# %% [markdown]
# **Answer:** Variable is a placeholder which store the information. String is a type of information which will be stored in variable.

# %% [markdown]
# ### **3. Describe three different data types.**

# %% [markdown]
# **Answer:** Python has the following data types built-in by default, in these categories:
#
#
# ``` python
# Text Type:	    str
# Numeric Types:	int, float, complex
# Sequence Types:   list, tuple, range
# Mapping Type:	 dict
# Set Types:	    set, frozenset
# Boolean Type:	 bool
# Binary Types:	 bytes, bytearray, memoryview
# None Type:	    NoneType
# ```
# We can get the data type of any object/variable using **type()** function.

# %% [markdown]
# ### **4. What is an expression made up of ? What do all expressions do?**

# %% [markdown]
# **Answer:**  Expression is made up of ***identifiers***, ***literals*** and ***operators***. Expression is used to evaluate the value i.e. result of a expression is a singular piece of information.

# %% [markdown]
# ### **5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?**

# %% [markdown]
# **Answer:** Statements are everthing in any programming language. Which male single or multiple line of code. Expressions are statements as well.

# %% [markdown]
# ### **6. After running the following code, what does the variable bacon contain?**
#
#
# ``` python
# bacon = 22
# bacon+1
# ```

# %% [markdown]
# **Answer:** 22

# %% [markdown]
# ### **7. What should the values of the following two terms be?**
#
#
# ``` python
# 'spam' + 'spamspam'
# 'spam'*3
# ```

# %% [markdown]
# **Answer:**
#
#
# ``` python
# 'spam' + 'spamspam' # spamspamspam
# 'spam'*3            # spamspamspam
# ```

# %% [markdown]
# ### **8. Why is eggs a valid variable name while 100 is invalid?**

# %% [markdown]
# **Answer:** eggs is a valid varibale name is since it start will letter and contains the valid character. But 100 is start with digit which is invalid according to variable name rule.

# %% [markdown]
# ### **9. What three functions can be used to get the integer, floating-point number, or string version of a value?**

# %% [markdown]
# **Answer:** int(), float(), str()

# %% [markdown]
# ### **10. Why does this expression cause an error? How can you fix it?**
#
#
# ``` python
# 'I have eaten ' + 99 + ' burritos.'
# ```

# %% [markdown]
# **Answer:** Python is ***strict-typed*** programming language. This means to perform arithmetic operation all operands must be same data type here **99** is integer and other are string. So this expression will throw error.
#
# To fix this issue we have to convert **99** to string using `str()` function.
