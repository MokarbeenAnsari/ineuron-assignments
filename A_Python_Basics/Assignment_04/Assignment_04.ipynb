# %% [markdown]
# ### **Q1: What exactly is []?**

# %% [markdown]
# **Answer:** This is **`square bracket`**. We use this to create **`empty list`** in Python and to **`access the element`** of list.

# %% [markdown]
# ### **Q2: In a list of values stored in a variable called spam, how would you assign the value 'hello' as the third value? (Assume [2, 4, 6, 8, 10] are in spam.)**

# %% [markdown]
# **Answer:** **`spam[2] = 'hello'`**

# %% [markdown]
# **Let's pretend the spam includes the list ['a', 'b', 'c', 'd'] for the next three queries.**

# %% [markdown]
# ### **Q3: What is the value of spam[int(int('3' * 2)/11)]**

# %% [markdown]
# **Answer:** **`'d'`**

# %% [markdown]
# ### **Q4: What is the value of spam[-1]?**

# %% [markdown]
# Answer: **`'d'`**

# %% [markdown]
# ### **Q5: What is the value of spam[:2]?**

# %% [markdown]
# **Answer:** **`['a', 'b']`**

# %% [markdown]
# **Let's pretend bacon has the list [3.14, 'cat,' 11, 'cat,' True] for the next three questions.**

# %% [markdown]
# ### **Q6: What is the value of bacon.index('cat')?**

# %% [markdown]
# **Answer:** `1`

# %% [markdown]
# ### **Q7: How does bacon.append(99) change the look of the list value in bacon?**

# %% [markdown]
# **Answer:** **`[3.14, 'cat', 11, 'cat', True, 99]`**

# %% [markdown]
# ### **Q8: How does bacon.remove('cat') change the look of the list in bacon?**

# %% [markdown]
# **Answer:** `[3.14, 11, 'cat', True, 99]`

# %% [markdown]
# ### **Q9: What are the list concatenation and list replication operators?**

# %% [markdown]
# **Answer:**
#
# ```python
# # List concatenation operator(+): This add the two/more list
# list1 = [1, 2, 3]
# list2 = [4, 5, 6]
# list_sum = list1 + list2 # This will result: [1, 2, 3, 4, 5, 6]
#
# # List replication operator(*): This repeat the list with given integer.
# list_repl = list1 * 2 # This will result: [1, 2, 3, 1, 2, 3]
# ```

# %% [markdown]
# ### **Q10: What is difference between the list methods append() and insert()?**

# %% [markdown]
# **Answer:** `append()` method allow to add given element at the end of list whereas `insert()` allow to add given element at specified index in the list.

# %% [markdown]
# ### **Q11: What are the two methods for removing items from a list?**

# %% [markdown]
# **Answer:** `remove()` and `pop()`

# %% [markdown]
# ### **Q12: Describe how list values and string values are identical.**

# %% [markdown]
# **Answer:** Both are ordered sequence of element which can be access through square bracket.

# %% [markdown]
# ### **Q13: What's the difference between tuples and lists?**

# %% [markdown]
# **Answer:**
#
# | List | Tuple |
# |:-------|:-------|
# |Lists are mutable | Tuples are immutable |
# |The implication of iterations is Time-consuming | The implication of iterations is comparatively Faster|
# |The list is better for performing operations, such as insertion and deletion.| Tuple data type is appropriate for accessing the elements|
# |Lists consume more memory| Tuple consumes less memory as compared to the list|
# |Lists have several built-in methods| Tuple does not have many built-in methods|
# |The unexpected changes and errors are more likely to occur | In tuple, it is hard to take place|

# %% [markdown]
# ### **Q14: How do you type a tuple value that only contains the integer 42?**

# %% [markdown]
# **Answer:** `my_tuple = (42,)`

# %% [markdown]
# ### **Q15: How do you get a list value's tuple form? How do you get a tuple value's list form?**

# %% [markdown]
# **Answer:** We can create tuple from list using `tuple()` and from tuple to list using `list()`. Example given below:

# %%
my_list = [1, 2, 3, 4, 5]
my_tuple = [6, 7, 8, 9, 10]

new_list = list(my_tuple)     # Creating list from tuple
new_tuple = tuple(my_list)    # Creating tuple from list

print(new_list)
print(new_tuple)
# Out:
# [6, 7, 8, 9, 10]
# (1, 2, 3, 4, 5)

# %% [markdown]
# ### **Q16: Variables that "contain" list values are not necessarily lists themselves. Instead, what do they contain?**

# %% [markdown]
# **Answer**: References to list values.

# %% [markdown]
# ### **Q17: How do you distinguish between copy.copy() and copy.deepcopy()?**

# %% [markdown]
# **Answer:** Difference between shallow (`copy.copy()`) and deep (`copy.deepcopy()`) copy:
# - A shallow copy constructs a new compound object and then (to the extent possible) inserts references into it to the objects found in the original.
# - A deep copy constructs a new compound object and then, recursively, inserts copies into it of the objects found in the original.
