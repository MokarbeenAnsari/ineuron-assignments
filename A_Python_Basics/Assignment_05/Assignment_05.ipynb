# %% [markdown]
# ### **Q1: What does an empty dictionary's code look like?**

# %% [markdown]
# **Answer:** We can create empty dictionary intwo ways
# ```python
# dict_1 = {}        # Not preferable
# dict_2 = dict()    # Preferable
# ```

# %% [markdown]
# ### **Q2: What is the value of a dictionary value with the key 'foo' and the value 42?**

# %% [markdown]
# **Answer:** `{'foo': 42}`

# %% [markdown]
# ### **Q3: What is the most significant distinction between a dictionary and a list?**

# %% [markdown]
# **Answer:** In list index(key) of value(item) is always integer using which we can access the elements.
#
# In dictionary key(index) of value(item) could be anything which we specify at the time of creation. Using that we can access the element of dictionary.

# %% [markdown]
# ### **Q4: What happens if you try to access spam['foo'] if spam is {'bar': 100}?**

# %% [markdown]
# **Answer:** This will throw `KeyError` since key 'foo' does not exist in dictionary.

# %% [markdown]
# ### **Q5: If a dictionary is stored in spam, what is the difference between the expressions `'cat' in spam` and `'cat' in spam.keys()`?**

# %% [markdown]
# **Answer**: There is no difference. The **`in`** operator checks whether a value exists as a key in the dictionary.

# %% [markdown]
# ### **Q6: If a dictionary is stored in spam, what is the difference between the expressions `'cat' in spam` and `'cat' in spam.values()`?**

# %% [markdown]
# **Answer**: **`'cat' in spam`** checks whether there is a 'cat' key in the dictionary, while **`'cat' in spam.values() `**checks whether there is a value 'cat' for one of the keys in spam.

# %% [markdown]
# ### **Q7: What is a shortcut for the following code?**
# ```python
# if 'color' not in spam:
#   spam['color'] = 'black'
# ```

# %% [markdown]
# **Answer:** Using `setdefault()` method we can achieve this.Since if the key does not exist, insert the key, with the specified value.
#
# ```python
# spam.setdefault('color','black')
# ```

# %% [markdown]
# ### **Q8: How do you "pretty print" dictionary values using which module and function?**

# %% [markdown]
# **Answer**: `pprint.pprint()`
# ```python
# from pprint import pprint
# my_dict = {'one':1, 'two':2, 'three':3, 'four':4, 'five': 5}
# pprint(my_dict)
# ```
