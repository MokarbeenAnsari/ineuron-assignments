# %% [markdown]
# #### **Q1: Is the Python Standard Library included with PyInputPlus?**

# %% [markdown]
# **Answer:** `PyInputPlus` is not a part of the Python Standard Library, we must install it separately using pip.
# ```python
# # To install PyInputPlus
# pip install PyInputPlus
# ```
#
# Before using this we have to import:
# ```python
# import pyinputplus as pyip
# ```

# %% [markdown]
# #### **Q2: Why is PyInputPlus commonly imported with `import pyinputplus as pypi`?**

# %% [markdown]
# **Answer:** We import the module with `import pyinputplus as pyip` so that we can enter a shorter name when calling the module’s functions.

# %% [markdown]
# #### **Q3: How do you distinguish between `inputInt()` and `inputFloat()`?**

# %% [markdown]
# **Answer:**
# ```
# inputInt()   -> Expect integer value as input
# inputFloat() -> Expect float value as input
# ```

# %% [markdown]
# #### **Q4: Using PyInputPlus, how do you ensure that the user enters a whole number between 0 and 99?**

# %% [markdown]
# **Answer:** Using `min` and `max` argument in `inputInt()` function.
# ```python
# import pyinputplus as pyip
# num = pyip.inputInt(min=0, max=99)
# ```

# %% [markdown]
# ### **Q5: What is transferred to the keyword arguments `allowRegexes` and `blockRegexes`?**

# %% [markdown]
# **Answer:**
# ```
# allowRegexes : If the regex set in allowRegexes, matches any part of the input, the whole string will be valid.
# blockRegexes : If the regex set in blockRegexes matches any part of the input, the whole string will be invalid.
# ```

# %% [markdown]
# #### **Q6: If a blank input is entered three times, what does `inputStr(limit=3)` do?**

# %% [markdown]
# **Answer:** The function will raise `RetryLimitException`.

# %% [markdown]
# #### **Q7: If blank input is entered three times, what does `inputStr(limit=3, default='hello')` do?**

# %% [markdown]
# **Answer:** The function returns the value `'hello'`.
