# %% [markdown]
# ### **Q1: Why are functions advantageous to have in your programs?**

# %% [markdown]
# **Answer:**  The advantages of using functions are:
# - Reducing duplication of code
# - Decomposing complex problems into simpler pieces
# - Improving clarity of the code
# - Reuse of code
# - Information hiding

# %% [markdown]
# ### **Q2: When does the code in a function run: when it's specified or when it's called?**

# %% [markdown]
# **Answer:** When It's called.

# %% [markdown]
# ### **Q3: What statement creates a function?**

# %% [markdown]
# **Answer:** A function is created with **`def`** keyword.

# %% [markdown]
# ### **Q4: What is the difference between a function and a function call?**

# %% [markdown]
# **Answer:**
#
# **Function:** When we write a block of code using the **`def`** keyword that code block is called *function*.
#
# **Function call:** When we execute that code block using the name of function, that statement is called *function call*.

# %% [markdown]
# ### **Q5: How many global scopes are there in a Python program? How many local scopes?**

# %% [markdown]
# **Answer:** A variable is only available from inside the region it is created. This is called **`scope`**.
#
# **Local scope:** A variable created inside a function belongs to the **`local scope`** of that function, and can only be used inside that function.
#
# **Global scope:** A variable created in the main body of the Python code is a global variable and belongs to the **`global scope`**.
#
# Global variables are available from within any scope, global and local.
#
# **Global Keyword:** If you need to create a global variable, but are stuck in the local scope, you can use the **`global`** keyword.
#
# The **`global`** keyword makes the variable global.

# %% [markdown]
# ### **Q6:What happens to variables in a local scope when the function call returns?**

# %% [markdown]
# **Answer:** When the execution of the function terminates (returns), the local variables are destroyed. This because the local variables disappear after the function returns.

# %% [markdown]
# ### **Q7: What is the concept of a return value? Is it possible to have a return value in an expression?**

# %% [markdown]
# **Ansaer:** A return statement is used to end the execution of the function call and returns the result. Yes In return statement there could be expression.

# %% [markdown]
# ### **Q8: If a function does not have a return statement, what is the return value of a call to that function?**

# %% [markdown]
# **Answer**: **`None`**

# %% [markdown]
# ### **Q9: How do you make a function variable refer to the global variable?**

# %% [markdown]
# **Answer:** Using `global` keyword.
#
# ```python
# x = 10
# def my_function():
#   global x
#   x = 15
#   print(x)
#
# print(x)      # This will print 10
# my_function() # This will print 15
#
# ```

# %% [markdown]
# ### **Q10: What is the data type of** **`None`**?

# %% [markdown]
# **Answer:** The None keyword is used to define a null value, or no value at all. None is not the same as 0, False, or an empty string. None is a data type of its own (NoneType) and only None can be None.

# %% [markdown]
# ### **Q11: What does the sentence `import areallyourpetsnamederic` do?**

# %% [markdown]
# **Answer**: `import` statement will import the module areallyourpetsnamederic so that we can we all functions/variable in current from that module.

# %% [markdown]
# ### **Q12: If you had a bacon() feature in a spam module, what would you call it after importing spam?**

# %% [markdown]
# **Answer:** `spam.bacon()`

# %% [markdown]
# ### **Q13: What can you do to save a programme from crashing if it encounters an error?**

# %% [markdown]
# **Answer:** We can do error handing using **`try`** and except **`block`**.

# %% [markdown]
# ### **Q14: What is the purpose of the try clause? What is the purpose of the except clause?**

# %% [markdown]
# **Answer:**
#
# **`try`** block:  Test a block of code for errors.
#
# **`except`** block:  Handle the error.
